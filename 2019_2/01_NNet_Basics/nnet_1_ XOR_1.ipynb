# %%
# Импорт библиотек
import numpy as np
import pandas as pd

# Импорт matplotlib - не нужен, на всякий случай

import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# Импорт нужного из keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

from keras import optimizers
from keras import initializers
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Задаем рабочую папку

import os
os.chdir("C:/Users/USER/Documents/Python/_AD_Python_part_4_NNet/01_NNet_Basics")

# %%
# Импорт обучающей выборки
zzz = pd.read_csv('data_XOR.txt', sep=',', header=0)

# %%
# zzz.head()

print(zzz)
# Out:
#    x1  x2  Y
# 0   1   1  0
# 1   0   0  0
# 2   0   1  1
# 3   1   0  1

# %%
#  Вариант
# Создаю обучающую выборку
#  zzz = pd.DataFrame({ 'x1' : [0, 0, 1., 1.], 
#                       'x2' : [0, 1., 0, 1.],
#                        'Y' : [0, 1., 1., 0] })

# %%
zzz.columns
# Out:
# Index(['x1', 'x2', 'Y'], dtype='object')

# %%
type(zzz)
# Out:
# pandas.core.frame.DataFrame

# %%
#  предикторы и отклик разделяем
# Отклик - группирующая переменная -  вектор y
y = zzz['Y']
# Предикторы - таблица X
X = zzz.drop('Y', axis=1)

# %%
np.random.seed(1234)

# %%
i = 2015

i
# Out:
# 2015

# %%
i = i + 1

# init_2 = initializers.TruncatedNormal(mean=0.0, stddev=0.5, seed=i)

init_2 = initializers.TruncatedNormal(mean=0.0, stddev=5, seed=i)
init_3 = initializers.Constant(value = 1e-3)

# Creating a model
model = Sequential()
model.add(Dense(4, input_dim=2, activation='sigmoid', kernel_initializer=init_2, bias_initializer=init_3))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init_2, bias_initializer=init_3))

sgd = optimizers.SGD(lr=0.1)


# Compiling model

#  долгий поиск решения
# model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])

#  быстрый поиск решения
model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])

# %%
# Training a model
model.fit(X, y, epochs=5000, batch_size=4, verbose = 0)

#  evaluate the model
scores = model.evaluate(X, y)
print("\nAccuracy: %.2f%%" % (scores[1]*100))
#  print('i=',  i, scores)

predictions = model.predict(X)

rounded = [round(x[0], 3) for x in predictions]
print('i=',  i, rounded)
# Out:
# 4/4 [==============================] - 0s 18ms/step
#
# Accuracy: 100.00%
# i= 2016 [0.236, 0.014, 0.805, 0.849]

# %%
scores
# Out:
# [0.02909643016755581, 1.0]

# %%
i = 2015

i

# %%
#  Объединяю две предыдущие ячейки

while True:
    i = i + 1

    # init_2 = initializers.TruncatedNormal(mean=0.0, stddev=0.5, seed=i)
    init_2 = initializers.TruncatedNormal(mean=0.0, stddev=5, seed=i)

    # Creating a model
    model = Sequential()
    model.add(Dense(4, input_dim=2, activation='sigmoid', kernel_initializer=init_2, bias_initializer=init_3))
    # model.add(Dense(2, input_dim=2, activation='sigmoid', kernel_initializer=init_2, bias_initializer=init_3))
    model.add(Dense(1, activation='sigmoid', kernel_initializer=init_2, bias_initializer=init_3))

    # Compiling model
    # model.compile(loss='mean_squared_error', optimizer='SGD', metrics=['accuracy'])
    # model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])
    model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])

    # Training a model
    model.fit(X, y, epochs=8000, batch_size=4, verbose = 0)

    # evaluate the model
    scores = model.evaluate(X, y)
    print('i=',  i, scores)
    if scores[1]>0.75:
        break

print("\nAccuracy: %.2f%%" % (scores[1]*100))

predictions = model.predict(X)

rounded = [round(x[0], 3) for x in predictions]
print(rounded)
# Out:
# 4/4 [==============================] - 0s 18ms/step
# i= 2019 [0.2629818916320801, 0.75]
# 4/4 [==============================] - 0s 21ms/step
# i= 2020 [0.250297486782074, 0.75]
# 4/4 [==============================] - 0s 18ms/step
# i= 2021 [0.14733995497226715, 0.5]
# 4/4 [==============================] - 0s 20ms/step
# i= 2022 [0.2568129003047943, 0.75]
# 4/4 [==============================] - 0s 27ms/step
# i= 2023 [0.1373118907213211, 0.75]
# 4/4 [==============================] - 0s 28ms/step
# i= 2024 [0.14670097827911377, 0.75]
# 4/4 [==============================] - 0s 25ms/step
# i= 2025 [0.2517770528793335, 0.75]
# 4/4 [==============================] - 0s 54ms/step
# i= 2026 [0.294234037399292, 0.75]
# 4/4 [==============================] - 0s 31ms/step
# i= 2027 [0.23785394430160522, 0.75]
# 4/4 [==============================] - 0s 46ms/step
# i= 2028 [0.25082823634147644, 0.75]
# 4/4 [==============================] - 0s 36ms/step
# ...

# %%
# Creating a model
model = Sequential()
model.add(Dense(9, input_dim=13, activation='relu'))
model.add(Dense(10, activation='relu', ))
model.add(Dense(3, activation='softmax'))


# Compiling model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


# Training a model
model.fit(X_train, y_train_bin, epochs=300, batch_size=10)
# Out:
# Epoch 1/300
# 119/119 [==============================] - 0s 2ms/step - loss: 5.1846 - acc: 0.5714
# Epoch 2/300
# 119/119 [==============================] - 0s 202us/step - loss: 4.6744 - acc: 0.6303
# Epoch 3/300
# 119/119 [==============================] - 0s 143us/step - loss: 4.7224 - acc: 0.6134
# Epoch 4/300
# 119/119 [==============================] - 0s 210us/step - loss: 4.6490 - acc: 0.6218
# Epoch 5/300
# 119/119 [==============================] - 0s 159us/step - loss: 4.7271 - acc: 0.6134
# Epoch 6/300
# 119/119 [==============================] - 0s 168us/step - loss: 4.7002 - acc: 0.6471
# Epoch 7/300
# 119/119 [==============================] - 0s 261us/step - loss: 4.6301 - acc: 0.6134
# Epoch 8/300
# 119/119 [==============================] - 0s 252us/step - loss: 4.6719 - acc: 0.6218
# Epoch 9/300
# 119/119 [==============================] - 0s 177us/step - loss: 4.6948 - acc: 0.6218
# Epoch 10/300
# ...

# %%
# evaluate the model
scores = model.evaluate(X_test, y_test_bin)
print("\nAccuracy: %.2f%%" % (scores[1]*100))
# Out:
# 59/59 [==============================] - 0s 983us/step
#
# Accuracy: 62.71%

# %%
# calculate predictions
predictions = model.predict(X_test)
# round predictions
# rounded = [round(x[0]) for x in predictions]
# print(rounded)

# %%
print(predictions[0:5])
# Out:
# [[3.0074161e-01 0.0000000e+00 6.9925833e-01]
#  [2.2982089e-01 0.0000000e+00 7.7017915e-01]
#  [5.7817298e-01 0.0000000e+00 4.2182696e-01]
#  [9.9435896e-01 0.0000000e+00 5.6410097e-03]
#  [1.9473886e-02 1.7381439e-36 9.8052615e-01]]
